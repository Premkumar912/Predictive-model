# %% [markdown]
# <a href="https://colab.research.google.com/github/Premkumar912/Predictive-model/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydub
# !pip install SpeechRecognition
# !pip install transformers
# !pip install torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 33.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 61.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 49.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 4.1 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=af5369f6935b36fcdb196ab279297e78f71ecf26231c60b99bd90e9b04c50327
#   Stored in directory: /root/.cache/pip/wheels/39/17/6f/66a045ea3d168826074691b4b787b8f324d3f646d755443fda
# Successfully built googletrans
# ...
#   Attempting uninstall: hyperframe
# ...

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-fdcc9d6f-d7b7-4d6b-8daa-8e826996d0f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdcc9d6f-d7b7-4d6b-8daa-8e826996d0f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pydub import AudioSegment
audio=AudioSegment.from_mp3("/content/speech (3) (1).mp3")
audio.export("converted.wav",format="wav")
# Out:
# <_io.BufferedRandom name='converted.wav'>

# %%
import speech_recognition as sr

recognizer = sr.Recognizer()
with sr.AudioFile("converted.wav") as source:
    audio_data = recognizer.record(source)
    text = recognizer.recognize_google(audio_data)

print("Full Transcript:\n")
print(text)
# Out:
# Full Transcript:
#
# good morning / afternoon everyone thank you so much for taking the time to be here today it's always a pleasure to come together as a team to share our ideas celebrate our progress and set the stage for what's next meetings like this aren't just about discussing numbers or checking tasks off a list they are about connection teamwork and reminding ourselves of the bigger picture we're working tomorrow and before we get into the agenda I'd like to take a moment to appreciate each one of you for your positive attitude the past few weeks have been both communication weather by Target and your energy let's keep supporting one another celebrating the small wins and striving for excellence in everything we do I look forward to hearing your thoughts and ideas in today's meeting and I'm confident that together we will continue to make great progress let's make this meeting productive inspiring and reflection of the amazing we are thank you and let's get started

# %%
from transformers import pipeline

# %%
s=pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# ...

# %%
summary=s(text)
summary[0].get('summary_text')
# Out:
# " Meetings like this aren't just about discussing numbers or checking tasks off a list they are about connection teamwork and reminding ourselves of the bigger picture . I'm confident that together we will continue to make great progress let's make this meeting productive inspiring and reflection of the amazing we are thank you and let's get started ."

# %%
import smtplib
from email.message import EmailMessage


smtp_host = "sandbox.smtp.mailtrap.io"
smtp_port = 587
smtp_user = "your_mailtrap_username"
smtp_pass = "your_mailtrap_password"


msg = EmailMessage()
msg['Subject'] = 'Meeting Summary from AI Agent'
msg['From'] = 'you@example.com'
msg['To'] = 'test@inbox.mailtrap.io'
msg.set_content(text)


try:
    with smtplib.SMTP(smtp_host, smtp_port) as server:
        server.starttls()
        server.login(smtp_user, smtp_pass)
        server.send_message(msg)
    print(" Summary emailed successfully to Mailtrap inbox!")
except Exception as e:
    print(" Email failed:", e)
# Out:
#  Email failed: Connection unexpectedly closed

# %%
qa=pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# ...

# %%
a=pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# ...

# %%
print("\n Choose an option:")
print("1 - Show Meeting Summary")
print("2 - Email the Summary")
print("3 - Ask Questions About the Summary")
print("4 - Sentiment Analysis")
print("5 - Translate Summary")

choice = input("\nEnter your choice (1-5): ")

if choice == "1":
    print("\n text:\n")
    print(text)

elif choice == "2":
    sender_email = input("Enter your Gmail: ")
    app_password = input("Enter your App Password: ")
    receiver_email = input("Enter recipient's email: ")

    msg = EmailMessage()
    msg.set_content(text)
    msg['Subject'] = "Meeting Summary"
    msg['From'] = sender_email
    msg['To'] = receiver_email

    try:
        with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
            smtp.login(sender_email, app_password)
            smtp.send_message(msg)
        print(" Email sent successfully!")
    except Exception as e:
        print("Email failed:", e)

elif choice == "3":
    qa_pipeline = pipeline("question-answering")
    while True:
        question = input("Ask a question (or type 'exit'): ")
        if question.lower() == "exit":
            break
        result = qa_pipeline(question=question, context=text)
        print("Answer:", result['answer'])

elif choice == "4":
    a=pipeline("sentiment-analysis")
    result = a(text)
    print(result)


elif choice == "5":
    translator = Translator()
    lang_code = input("Enter language code (e.g., 'fr', 'es', 'de'): ")
    translated = translator.translate(text, dest=lang_code)
    print(f"\nTranslated Summary ({lang_code}):\n{translated.text}")

else:
    print("Invalid choice. Please select a number between 1 and 5.")
# Out:
#  Choose an option:
# 1 - Show Meeting Summary
# 2 - Email the Summary
# 3 - Ask Questions About the Summary
# 4 - Sentiment Analysis
# 5 - Translate Summary
